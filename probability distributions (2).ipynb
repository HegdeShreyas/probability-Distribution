# %% [markdown]
# # Binomial distribution

# %%
import numpy as np
np.random.binomial(100,0.2)
# Out:
# 22

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
x=random.binomial(n=100,p=0.4,size=500)
sns.histplot(x,kde=False)
plt.show()

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
x=random.binomial(n=100,p=0.4,size=500)
sns.histplot(x,kde=False)
plt.show()

# %% [markdown]
# # poisson distribution

# %%
np.random.poisson(5.6,10)
# Out:
# array([ 7,  9,  6,  5,  5,  4,  6, 10,  6,  5])

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

x=random.poisson(0.6,size=500)
sns.kdeplot(x)
plt.show()

# %% [markdown]
# # Normal distribution

# %%
np.random.normal(10,5,10)
# Out:
# array([ 6.87281603,  9.86942018,  8.01142592,  5.15289236,  6.12390491,
#         0.46505302, 14.0190339 , 11.15590142, 16.56624362, 10.09743636])

# %%
x=random.normal(10,0.4,size=500)
sns.kdeplot(x)
plt.show()

# %%
sns.kdeplot(random.normal(loc=50,scale=5,size=1000),label='normal')
sns.kdeplot(random.binomial(n=100,p=0.5,size=3250),label='binomial')
plt.show()

# %%
sns.kdeplot(random.normal(loc=50,scale=5,size=1000),label='normal')
sns.kdeplot(random.binomial(n=100,p=0.5,size=3250),label='binomial')
sns.kdeplot(random.poisson(lam=50,size=5000),label='poisson')
plt.show()

# %%
from scipy.stats import binom
p=0.3
k=100
dist=binom(k,p)
for n in range(10,110,10):
    print('p of %d success:%.2f%%'%(n,dist.pmf(n)*100))
# Out:
# p of 10 success:0.00%
# p of 20 success:0.76%
# p of 30 success:8.68%
# p of 40 success:0.85%
# p of 50 success:0.00%
# p of 60 success:0.00%
# p of 70 success:0.00%
# p of 80 success:0.00%
# p of 90 success:0.00%
# p of 100 success:0.00%

# %%
import scipy
s=scipy.stats.bernoulli(0.6)
print(s)

# %%
from scipy import stats
stats.t.ppf(0.975,df=139)
# Out:
# 1.977177724476122

# %%
import scipy.stats as stats
import math

# Specify the number of occurrences (x), the sample size (n), and the proportion claimed in the null-hypothesis (p)
x = 10
n = 100
p = 0.5

# Calculate the sample proportion
p_hat = x/n

# Calculate and print the test statistic
print((p_hat-p)/(math.sqrt((p*(1-p))/(n))))
# Out:
# -8.0

# %%
import numpy as np
import matplotlib.pyplot as plt

data = [24.23, 25.53, 25.41, 24.14, 29.62, 28.25, 25.81, 24.39, 40.26, 32.95, 91.36, 25.99, 39.42, 26.71, 35.00]

# Calculate mean, standard deviation, and variance
mean = np.mean(data)
std_dev = np.std(data)
variance = np.var(data)

# Create a box plot to visualize outliers
plt.boxplot(data)
plt.title("Box Plot of Measure X")
plt.ylabel("Measure X")
plt.show()

print("Mean (μ):", mean)
print("Standard Deviation (σ):", std_dev)
print("Variance (σ^2):", variance)
# Out:
# Mean (μ): 33.27133333333333
# Standard Deviation (σ): 16.370812590976932
# Variance (σ^2): 268.00350488888887
